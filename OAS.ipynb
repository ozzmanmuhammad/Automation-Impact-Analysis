# %% [markdown]
# # Occupations, Salaries by State and Likelihood of Automation
#
# ## Dataset:
# We are going to use following datasets:
#
#
# 1.   [Salaries, median hourly/annual wages broke down by occupation, provided by BLS May 2021.](https://www.bls.gov/oes/current/oes_nat.htm#11-0000)
# 2.   [Risk of automation broken down by occupation, provided by Carl Benedikt Frey and Michael A. Osborne](https://data.world/wnedds/occupations-by-state-and-likelihood-of-automation)
# 3. [Education and training assignments by detailed occupation](https://www.bls.gov/emp/tables/education-and-training-by-occupation.htm)
# 4. [Educational attainment for workers 25 years and older by detailed occupation](https://www.bls.gov/emp/tables/educational-attainment.htm)

# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

from textwrap import wrap

# %% [markdown]
# ## Preprocessing the Dataset

# %% [markdown]
# Set the path here

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1_path = '/content/drive/MyDrive/FYP/OAS/national_M2021_dl.xlsx'
data2_path = '/content/drive/MyDrive/FYP/OAS/raw_state_automation_data.csv'
data3_path = '/content/drive/MyDrive/FYP/OAS/education.xlsx'

# %% [markdown]
# ### Importing Salary Dataset
#
# I list the ones that are not obvious below:
#
# * **OCC_GROUP** - The category of the size of the group. Total > Major > Minor > Broad > Detailed
# * **EMP_PRSE** - Employment Relative Standard Error (i.e. how accurate the information is with higher numbers being bad)
# * **H_MEAN** - Mean hourly wage
# * **A_MEAN** - Mean annual wage
# * **MEAN_PRSE** - Mean wage Relative Standard Error
# * **H_PCT_10** - Hourly wage 10 percentile
# * **H_PCT_25** - Hourly wage 25 percentile
# * etc..

# %%
df1 = pd.read_excel(data1_path, sheet_name='national_M2021_dl')

# %%
df1.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
df1.head()
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 0    99       U.S.          1         US      0  Cross-industry
# 1    99       U.S.          1         US      0  Cross-industry
# 2    99       U.S.          1         US      0  Cross-industry
# 3    99       U.S.          1         US      0  Cross-industry
# 4    99       U.S.          1         US      0  Cross-industry
#
#           I_GROUP  OWN_CODE OCC_CODE               OCC_TITLE  ... H_MEDIAN  \
# 0  cross-industry      1235  00-0000         All Occupations  ...       22
# 1  cross-industry      1235  11-0000  Management Occupations  ...    49.25
# 2  cross-industry      1235  11-1000          Top Executives  ...    47.46
# 3  cross-industry      1235  11-1010        Chief Executives  ...    86.31
# 4  cross-industry      1235  11-1011        Chief Executives  ...    86.31
#
#    H_PCT75  H_PCT90  A_PCT10  A_PCT25  A_MEDIAN  A_PCT75 A_PCT90 ANNUAL HOURLY
# 0    32.98    49.43    23980    29950     45760    68590  102810    NaN    NaN
# 1    77.39        #    47860    74710    102450   160960       #    NaN    NaN
# 2    77.18        #    41260    60900     98720   160540       #    NaN    NaN
# 3        #        #    60300   111080    179520        #       #    NaN    NaN
# 4        #        #    60300   111080    179520        #       #    NaN    NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Importing Automation Dataset
#
# **Note:** Perhaps most importantly, the Probability column in automation_data represents the probability of the occupation being automated with a probability greater than 0.7 representing a **`high risk category, meaning that associated occupations are potentially automatable over some unspecified number of years, perhaps a decade or two`**

# %%
df2 = pd.read_csv(data2_path, encoding = "ISO-8859-1")
states = df2.columns[3:]

# %%
len(states)
# Out:
# 51

# %%
df2.head()
# Out:
#        SOC                           Occupation  Probability  Alabama  Alaska  \
# 0  11-1011                     Chief Executives        0.015     1030     760
# 1  11-1021      General and Operations Managers        0.160    26930    6490
# 2  11-2011  Advertising and Promotions Managers        0.039       50      40
# 3  11-2021                   Marketing Managers        0.014      530     200
# 4  11-2022                       Sales Managers        0.013     2510     400
#
#    Arizona  Arkansas  California  Colorado  Connecticut  ...  South Dakota  \
# 0     5750      2710       31150       880         1410  ...           560
# 1    43300     20680      261780     41540        33280  ...          3730
# 2      470       110        3760       480          300  ...             0
# 3     4790      1090       33390      3060         4970  ...            60
# 4    10650      2650       69180      4570         7040  ...           300
#
#    Tennessee   Texas   Utah  Vermont  Virginia  Washington  West Virginia  \
# 0       5460    5890   3650      280      6320        5910            980
# 1      44400  168610  36200     2760     52380       43760          10200
# 2        670    1210    380       40       240         640             40
# 3       3400    9570   2320      380      3840        5830            260
# 4       8890   22310   3360      480      5360        7390            600
#
#    Wisconsin  Wyoming
# 0       3740      160
# 1      32350     4840
# 2        200        0
# 3       2980       30
# 4       5730      180
#
# [5 rows x 54 columns]

# %% [markdown]
# ### Importing education data

# %%
df3 = pd.read_excel(data3_path, sheet_name='Table 5.3', skiprows=1)
df3.head()
# Out:
#   2021 National Employment Matrix title 2021 National Employment Matrix code  \
# 0                Total, all occupations                              00-0000
# 1                   Chief executives(1)                              11-1011
# 2       General and operations managers                              11-1021
# 3                        Legislators(1)                              11-1031
# 4   Advertising and promotions managers                              11-2011
#
#    Less than high school diploma  High school diploma or equivalent  \
# 0                            8.0                               23.6
# 1                            1.5                                8.3
# 2                            2.6                               17.0
# 3                            1.5                                8.3
# 4                            0.8                                3.9
#
#    Some college, no degree  Associate's degree  Bachelor's degree  \
# 0                     20.2                 9.6               23.7
# 1                     14.2                 5.1               40.5
# 2                     24.8                 9.8               33.0
# 3                     14.2                 5.1               40.5
# 4                     10.8                 6.0               63.6
#
#    Master's degree  Doctoral or professional degree
# 0             10.6                              4.4
# 1             23.7                              6.7
# 2             11.1                              1.6
# 3             23.7                              6.7
# 4             12.8                              2.1

# %%
education1 = df3.drop(df3.columns[1], axis=1)
education1 = education1.rename(columns={"2021 National Employment Matrix title": "occupation",
                                       "Less than high school diploma": "lessthanhs",
                                       "High school diploma or equivalent": "hsdiploma",
                                       "Some college, no degree": "somecollege",
                                       "Associate's degree": "associates",
                                       "Bachelor's degree": "bachelors",
                                       "Master's degree": "masters",
                                       "Doctoral or professional degree": "professional"})

education2 = education1.groupby('occupation').agg({
    'lessthanhs': 'sum',
    'hsdiploma': 'sum',
    'somecollege': 'sum',
    'associates': 'sum',
    'bachelors': 'sum',
    'masters': 'sum',
    'professional': 'sum'
}).reset_index()

education2['hsorless'] = education2['lessthanhs'] + education2['hsdiploma']
education2['somecollegeorassociates'] = education2['somecollege'] + education2['associates']
education2['postgrad'] = education2['masters'] + education2['professional']

education_data1 = education2.dropna().drop(0)
education_data1['occupation'] = education_data1['occupation'].str.lower()

# %%
education_data1.head()
# Out:
#                                        occupation  lessthanhs  hsdiploma  \
# 1                        accountants and auditors         0.0        3.0
# 2                                          actors         2.1       14.0
# 3                                       actuaries         0.0        0.0
# 4                                  acupuncturists         1.1        1.4
# 5  adhesive bonding machine operators and tenders        18.7       43.3
#
#    somecollege  associates  bachelors  masters  professional  hsorless  \
# 1          5.5         8.0       57.0     23.4           3.0       3.0
# 2         16.5         5.4       47.9     13.2           0.9      16.1
# 3          2.0         0.4       62.2     23.8          11.7       0.0
# 4          2.6         1.2       13.3     51.0          29.5       2.5
# 5         21.8        12.8        1.5      1.9           0.0      62.0
#
#    somecollegeorassociates  postgrad
# 1                     13.5      26.4
# 2                     21.9      14.1
# 3                      2.4      35.5
# 4                      3.8      80.5
# 5                     34.6       1.9

# %%
df4 = pd.read_excel(data3_path, sheet_name='Table 5.4', skiprows=1)

df4 = df4.rename(columns={"2021 National Employment Matrix title": "occupation",
                                       "Typical education needed for entry": "typical",
                                       "Work experience in a related occupation": "workexp"})

typicaleducation_data = df4[['occupation', 'typical', 'workexp']]
typicaleducation_data = typicaleducation_data.dropna()
typicaleducation_data['occupation'] = typicaleducation_data['occupation'].str.lower()
# typicaleducation_data = typicaleducation_data.rename(columns={ 'occupation':'Occupation'})

# %%
typicaleducation_data.head()
# Out:
#                             occupation            typical            workexp
# 0                     chief executives  Bachelor's degree    5 years or more
# 1      general and operations managers  Bachelor's degree    5 years or more
# 2                          legislators  Bachelor's degree  Less than 5 years
# 3  advertising and promotions managers  Bachelor's degree  Less than 5 years
# 4                   marketing managers  Bachelor's degree    5 years or more

# %% [markdown]
# ### Joining the datasets
#
# For my next step, I'm going to look at how compatible the datatables are. The tables are not from the same original source as one comes from a research paper and the other from the US Bureau of Labor Statistics. In an ideal world, I could just join the tables together matching Occupation to OCC_TITLE, but before I do I should check to see how much overlap there is.

# %%
temp_occ_1 = df1['OCC_TITLE'].unique()
temp_occ_2 = df2['Occupation'].unique()
len(temp_occ_1) , len(temp_occ_2)
# Out:
# (1138, 702)

# %%
# what I've done first is check what percent of unique occupations in the
# automation_data table are in the occupation_salary table
total_diff = len(np.setdiff1d(temp_occ_1, temp_occ_2))
percent_diff = f"{len(np.intersect1d(temp_occ_2, temp_occ_1)) / len(temp_occ_2) * 100: .1f}%"
print(f"Total different values are: {total_diff}, contributing: {percent_diff}")
# Out:
# Total different values are: 730, contributing:  58.1%

# %% [markdown]
# **Note:** something is wrong as it is showing only 58% overlapping we'll look into the fields
#
# it turned out to primarily be a simple string substitution. Since automation_data was originally in a CSV format, the creator of the original file used semi-colons instead of the commas used in the occupation_salary table.

# %%
temp_occ_2 = np.array([re.sub(';', ',', s) for s in temp_occ_2])

# %%
total_diff = len(np.setdiff1d(temp_occ_1, temp_occ_2))
percent_diff = f"{len(np.intersect1d(temp_occ_2, temp_occ_1)) / len(temp_occ_2) * 100: .1f}%"
print(f"Total different values are: {total_diff}, contributing: {percent_diff}")
# Out:
# Total different values are: 552, contributing:  83.5%

# %% [markdown]
# For my next step,
#
#
# 1.   I needed to join the two tables together. I started by doing the string substitution on the automation_data table and by adding a **State_Total** column to that dataset, so that I could compare it to the **TOT_EMP** variable from the occupation_salary table.
# 2.   I wanted to do was ensure that every occupation's salary was measured annually. Looking at the dataset, it became clear that virtually all annual mean salaries were simply the hourly salary *multiplied by 2080 (40 hours a week, 52 weeks in a year)*. I took both columns and converted them to numeric variables and then replaced the missing values in **A_MEAN** with a calculated value based on **H_MEAN**
# 3. I joined the two tables together using an **inner join** to ensure that every occupation in the combined table has a **Mean Annual Salary, Total Employment value, a Sum of the Employment by State, and a Probability of Automation**

# %%
df1.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
automation_data2 = df2.copy()
automation_data2['Occupation'] = automation_data2['Occupation'].str.replace(';', ',')
automation_data2['State_Total'] = automation_data2.iloc[:, 4:54].sum(axis=1)

occupation_salary_red = df1[['OCC_TITLE', 'O_GROUP', 'TOT_EMP', 'EMP_PRSE', 'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'A_MEDIAN']].drop_duplicates()
occupation_salary_red['H_MEAN'] = pd.to_numeric(occupation_salary_red['H_MEAN'], errors='coerce')
occupation_salary_red['A_MEAN'] = pd.to_numeric(occupation_salary_red['A_MEAN'], errors='coerce')

occupation_salary_red.loc[occupation_salary_red['A_MEAN'].isna(), 'A_MEAN'] = occupation_salary_red.loc[occupation_salary_red['A_MEAN'].isna(), 'H_MEAN'] * 2080

occupation_salary_red = occupation_salary_red.drop(columns=['H_MEAN'])

combined_data = pd.merge(occupation_salary_red, automation_data2.drop(columns=['SOC']), how='inner', left_on='OCC_TITLE', right_on='Occupation')
combined_data = combined_data.dropna(subset=['State_Total'])
combined_data = combined_data.rename(columns={ 'Occupation':'occupation'})

# %%
typicaleducation_data['occupation'] #831
# Out:
# 0                               chief executives
# 1                general and operations managers
# 2                                    legislators
# 3            advertising and promotions managers
# 4                             marketing managers
#                          ...
# 827      pump operators, except wellhead pumpers
# 828                             wellhead pumpers
# 829    refuse and recyclable material collectors
# 830            tank car, truck, and ship loaders
# 831           material moving workers, all other
# Name: occupation, Length: 832, dtype: object

# %%
combined_data.head() #803
# Out:
#                              OCC_TITLE   O_GROUP  TOT_EMP  EMP_PRSE    A_MEAN  \
# 0                     Chief Executives     broad   200480       1.6  213020.0
# 1                     Chief Executives  detailed   200480       1.6  213020.0
# 2      General and Operations Managers     broad  2984920       0.5  115250.0
# 3      General and Operations Managers  detailed  2984920       0.5  115250.0
# 4  Advertising and Promotions Managers     broad    22520       3.4  142860.0
#
#   MEAN_PRSE A_MEDIAN                           occupation  Probability  \
# 0       0.8   179520                     Chief Executives        0.015
# 1       0.8   179520                     Chief Executives        0.015
# 2       0.4    97970      General and Operations Managers        0.160
# 3       0.4    97970      General and Operations Managers        0.160
# 4       1.9   127150  Advertising and Promotions Managers        0.039
#
#    Alabama  ...  Tennessee   Texas   Utah  Vermont  Virginia  Washington  \
# 0     1030  ...       5460    5890   3650      280      6320        5910
# 1     1030  ...       5460    5890   3650      280      6320        5910
# 2    26930  ...      44400  168610  36200     2760     52380       43760
# 3    26930  ...      44400  168610  36200     2760     52380       43760
# 4       50  ...        670    1210    380       40       240         640
#
#    West Virginia  Wisconsin  Wyoming  State_Total
# 0            980       3740      160       222240
# 1            980       3740      160       222240
# 2          10200      32350     4840      2161940
# 3          10200      32350     4840      2161940
# 4             40        200        0        28030
#
# [5 rows x 61 columns]

# %%
# Replace ";" with "," in the "occupation" column and convert it to lowercase
combined_data['occupation'] = combined_data['occupation'].str.lower()

# Merge "edsal2" and "automation1" dataframes by "occupation"
combined_data_2 = pd.merge(typicaleducation_data, combined_data, on='occupation')

# %%
WAPE = f"{np.mean(abs(combined_data['State_Total'] - combined_data['TOT_EMP']) / np.mean(combined_data['TOT_EMP'])) * 100: .1f}%"

# %%
# print('Weighted Absolute Percentage Error (WAPE)', WAPE)

# %%
combined_data.columns
# Out:
# Index(['OCC_TITLE', 'O_GROUP', 'TOT_EMP', 'EMP_PRSE', 'A_MEAN', 'MEAN_PRSE',
#        'A_MEDIAN', 'occupation', 'Probability', 'Alabama', 'Alaska', 'Arizona',
#        'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'State_Total'],
#       dtype='object')

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Which occupations contribute most to the American economy (in USD).

# %%
temp1 = df1.groupby('OCC_TITLE').apply(lambda x: x.assign(natlwage=x['TOT_EMP'] * pd.to_numeric(x['A_MEAN'], errors='coerce')))
temp1 = temp1.dropna(subset=['TOT_EMP', 'A_MEAN', 'A_MEDIAN'])

temp1['A_MEDIAN'] = pd.to_numeric(temp1['A_MEDIAN'], errors='coerce')
temp2 = temp1[['OCC_TITLE', 'TOT_EMP', 'A_MEDIAN', 'natlwage']].drop_duplicates()

temp2 = temp2.sort_values(by='natlwage', ascending=False).reset_index(drop=True)
temp2 = temp2.rename(columns = {'OCC_TITLE' : 'occupation',
                                    'TOT_EMP' : 'Total Employees',
                                    'A_MEDIAN' : '$ Annual Median',
                                    'natlwage' : 'Net wage'})
temp2[1:11].to_csv('total_wages.csv')
# Out:
# <ipython-input-36-fea45379387f>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#
# 0                     13.5      26.4          1318550          77250.0
# 2                      2.4      35.5            23040         105900.0
# 3                      3.8      80.5             7250          60570.0
# 4                     34.6       1.9            12510          37630.0
# 5                     32.4      18.4           224620         100170.0
#
#        Net wage
# 0  1.107318e+11
# 2  2.886912e+09
# 3  5.203325e+08
# 4  4.826358e+08
# 5  2.538880e+10

# %%
typicaleducation_data.head()
# Out:
#                             occupation            typical            workexp
# 0                     chief executives  Bachelor's degree    5 years or more
# 1      general and operations managers  Bachelor's degree    5 years or more
# 2                          legislators  Bachelor's degree  Less than 5 years
# 3  advertising and promotions managers  Bachelor's degree  Less than 5 years
# 4                   marketing managers  Bachelor's degree    5 years or more

# %%
typicaleducation_data.shape, edsal.shape
# Out:
# ((832, 3), (368, 14))

# %%
edsal2 = pd.merge(edsal, typicaleducation_data, on='occupation')

edsal2.head()
# Out:
#                                        occupation  lessthanhs  hsdiploma  \
# 0                        accountants and auditors         0.0        3.0
# 1                                       actuaries         0.0        0.0
# 2                                  acupuncturists         1.1        1.4
# 3  adhesive bonding machine operators and tenders        18.7       43.3
# 4                administrative services managers         1.0       13.7
#
#    somecollege  associates  bachelors  masters  professional  hsorless  \
# 0          5.5         8.0       57.0     23.4           3.0       3.0
# 1          2.0         0.4       62.2     23.8          11.7       0.0
# 2          2.6         1.2       13.3     51.0          29.5       2.5
# 3         21.8        12.8        1.5      1.9           0.0      62.0
# 4         20.0        12.4       34.4     16.3           2.1      14.7
#
#    somecollegeorassociates  postgrad  Total Employees  $ Annual Median  \
# 0                     13.5      26.4          1318550          77250.0
# 1                      2.4      35.5            23040         105900.0
# 2                      3.8      80.5             7250          60570.0
# 3                     34.6       1.9            12510          37630.0
# 4                     32.4      18.4           224620         100170.0
#
#        Net wage                            typical            workexp
# 0  1.107318e+11                  Bachelor's degree               None
# 1  2.886912e+09                  Bachelor's degree               None
# 2  5.203325e+08                    Master's degree               None
# 3  4.826358e+08  High school diploma or equivalent               None
# 4  2.538880e+10                  Bachelor's degree  Less than 5 years

# %% [markdown]
# ### What is the median wage for each typical level of education?

# %%
edsal3 = edsal2.groupby('typical').agg({'$ Annual Median': 'mean'}).sort_values('$ Annual Median').reset_index()
edsal3
# Out:
#                              typical  $ Annual Median
# 0   No formal educational credential     32859.756098
# 1            Some college, no degree     41000.000000
# 2      Postsecondary nondegree award     43859.230769
# 3  High school diploma or equivalent     45767.142857
# 4                 Associate's degree     61823.125000
# 5                    Master's degree     82488.823529
# 6                  Bachelor's degree     83390.736842
# 7    Doctoral or professional degree     97990.000000

# %%
fig = px.bar(edsal3, x='typical', y='$ Annual Median', color=edsal3['typical'],
             title='Median Annual Income by Education Level',
             labels={'typical': 'Education Level', 'medianwage': 'Median Annual Income'},
        )
fig.update_xaxes(title_text=None, showticklabels=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="429db197-2a6a-48a0-9add-c6c6cd9914ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("429db197-2a6a-48a0-9add-c6c6cd9914ad")) {                    Plotly.newPlot(                        "429db197-2a6a-48a0-9add-c6c6cd9914ad",                        [{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"No formal educational credential","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No formal educational credential","offsetgroup":"No formal educational credential","orientation":"v","showlegend":true,"textposition":"auto","x":["No formal educational credential"],"xaxis":"x","y":[32859.756097560974],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"Some college, no degree","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Some college, no degree","offsetgroup":"Some college, no degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Some college, no degree"],"xaxis":"x","y":[41000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"Postsecondary nondegree award","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Postsecondary nondegree award","offsetgroup":"Postsecondary nondegree award","orientation":"v","showlegend":true,"textposition":"auto","x":["Postsecondary nondegree award"],"xaxis":"x","y":[43859.230769230766],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"High school diploma or equivalent","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"High school diploma or equivalent","offsetgroup":"High school diploma or equivalent","orientation":"v","showlegend":true,"textposition":"auto","x":["High school diploma or equivalent"],"xaxis":"x","y":[45767.142857142855],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"Associate's degree","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Associate's degree","offsetgroup":"Associate's degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Associate's degree"],"xaxis":"x","y":[61823.125],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"Master's degree","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Master's degree","offsetgroup":"Master's degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Master's degree"],"xaxis":"x","y":[82488.82352941176],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"Bachelor's degree","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Bachelor's degree","offsetgroup":"Bachelor's degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Bachelor's degree"],"xaxis":"x","y":[83390.73684210527],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=%{x}<br>$ Annual Median=%{y}<extra></extra>","legendgroup":"Doctoral or professional degree","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Doctoral or professional degree","offsetgroup":"Doctoral or professional degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Doctoral or professional degree"],"xaxis":"x","y":[97990.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcon ...

# %% [markdown]
# ### Visualize the probability of automation vs total employment:

# %%
combined_data.columns
# Out:
# Index(['OCC_TITLE', 'O_GROUP', 'TOT_EMP', 'EMP_PRSE', 'A_MEAN', 'MEAN_PRSE',
#        'A_MEDIAN', 'occupation', 'Probability', 'Alabama', 'Alaska', 'Arizona',
#        'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'State_Total'],
#       dtype='object')

# %%
combined_data_2.columns
# Out:
# Index(['occupation', 'typical', 'workexp', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'A_MEAN', 'MEAN_PRSE', 'A_MEDIAN', 'Probability', 'Alabama',
#        'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'State_Total'],
#       dtype='object')

# %%
combined_data_2['occupation'].drop_duplicates().to_csv('occupation.csv')

# %%
fig = px.scatter(combined_data, x='State_Total', y='Probability',
                 title='Probability of Automation vs Total Employment',
                 labels={'total': 'Number of Americans in a Given Job', 'probability': 'Probability of Automation'},
                 color_discrete_sequence=['red'])
fig.update_traces(opacity=1/3)
# fig.update_xaxes(type='log')
fig.update_yaxes(range=[0,1])
fig.add_trace(px.scatter(combined_data[combined_data['State_Total'] > 4000000], x='State_Total', y='Probability',
                 labels={'total': 'Number of Americans in a Given Job', 'probability': 'Probability of Automation'},
                 text='occupation', size_max=2.5).update_traces(textposition='top right', showlegend=False).data[0])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="
,97250,97250,221420,221420,41000,41000,175530,175530,135620,135620,984150,984150,135270,135270,88170,88170,72130,72130,195700,31090,31090,80680,323710,109790,319310,319310,72630,72630,628280,2249720,192350,65970,12740,12740,271550,271550,91070,91070,2922950,2922950,56920,56920,9480,9480,10010,10010,19050,19050,13200,13200,530,530,36270,36270,0,5820,5820,3720,24440,2550,527340,527340,1 ...

# %% [markdown]
# There doesn’t seem to be a huge relationship between automation and number of employees

# %% [markdown]
# ### Likelihood of Job Automation by Education Level

# %%
edu_vs_auto = combined_data_2.groupby('typical').agg({'Probability': 'mean'}).sort_values('Probability').reset_index()

# %%
edu_vs_auto
# Out:
#                              typical  Probability
# 0    Doctoral or professional degree     0.088572
# 1                    Master's degree     0.116591
# 2                  Bachelor's degree     0.205874
# 3                 Associate's degree     0.460835
# 4      Postsecondary nondegree award     0.486500
# 5  High school diploma or equivalent     0.710718
# 6   No formal educational credential     0.803514
# 7            Some college, no degree     0.824286

# %%
fig = px.bar(data_frame=edu_vs_auto, x='typical', y='Probability', color='typical',
             color_discrete_sequence=px.colors.qualitative.Pastel)

fig.update_traces(marker=dict(line=dict(color='black', width=0.5)), opacity=1)
fig.update_yaxes(title="Likelihood of Job Automation")
fig.update_layout(title="Likelihood of Job Automation by Education Level",
                  legend_title_text='Education Level',
                  showlegend=True,
                  legend=dict(itemclick=False, itemdoubleclick=False))
fig.update_xaxes(title=None, showticklabels=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dc17b440-7761-4abb-acdb-2fce062bb670" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc17b440-7761-4abb-acdb-2fce062bb670")) {                    Plotly.newPlot(                        "dc17b440-7761-4abb-acdb-2fce062bb670",                        [{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"Doctoral or professional degree","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""},"line":{"color":"black","width":0.5}},"name":"Doctoral or professional degree","offsetgroup":"Doctoral or professional degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Doctoral or professional degree"],"xaxis":"x","y":[0.08857200000000001],"yaxis":"y","type":"bar","opacity":1},{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"Master's degree","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""},"line":{"color":"black","width":0.5}},"name":"Master's degree","offsetgroup":"Master's degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Master's degree"],"xaxis":"x","y":[0.11659142857142858],"yaxis":"y","type":"bar","opacity":1},{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"Bachelor's degree","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""},"line":{"color":"black","width":0.5}},"name":"Bachelor's degree","offsetgroup":"Bachelor's degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Bachelor's degree"],"xaxis":"x","y":[0.20587379679144382],"yaxis":"y","type":"bar","opacity":1},{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"Associate's degree","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""},"line":{"color":"black","width":0.5}},"name":"Associate's degree","offsetgroup":"Associate's degree","orientation":"v","showlegend":true,"textposition":"auto","x":["Associate's degree"],"xaxis":"x","y":[0.46083529411764707],"yaxis":"y","type":"bar","opacity":1},{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"Postsecondary nondegree award","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""},"line":{"color":"black","width":0.5}},"name":"Postsecondary nondegree award","offsetgroup":"Postsecondary nondegree award","orientation":"v","showlegend":true,"textposition":"auto","x":["Postsecondary nondegree award"],"xaxis":"x","y":[0.4865],"yaxis":"y","type":"bar","opacity":1},{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"High school diploma or equivalent","marker":{"color":"rgb(158, 185, 243)","pattern":{"shape":""},"line":{"color":"black","width":0.5}},"name":"High school diploma or equivalent","offsetgroup":"High school diploma or equivalent","orientation":"v","showlegend":true,"textposition":"auto","x":["High school diploma or equivalent"],"xaxis":"x","y":[0.7107180055401663],"yaxis":"y","type":"bar","opacity":1},{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"No formal educational credential","marker":{"color":"rgb(254, 136, 177)","pattern":{"shape":""},"line":{"color":"black","width":0.5}},"name":"No formal educational credential","offsetgroup":"No formal educational credential","orientation":"v","showlegend":true,"textposition":"auto","x":["No formal educational credential"],"xaxis":"x","y":[0.8035142857142857],"yaxis":"y","type":"bar","opacity":1},{"alignmentgroup":"True","hovertemplate":"typical=%{x}<br>Probability=%{y}<extra></extra>","legendgroup":"Some college, no ...

# %% [markdown]
# ### Likelihood of Job Automation vs Median Income

# %%
fig = px.scatter(combined_data_2, x='A_MEAN', y='Probability', size='TOT_EMP', color='typical',
                 opacity=0.5, color_discrete_sequence=px.colors.qualitative.Vivid,
                 title='Likelihood of Job Automation vs Median Income',
                 labels={'A_MEDIAN': 'Median Income', 'probability': 'Probability of Automation'},
                 size_max=30, range_y=[-.01, 1])

fig.update_traces(marker=dict(line=dict(width=0.5, color='Black')))
fig.update_layout(showlegend=True, legend_title='Education Level', legend=dict(title_font=dict(size=10)))
fig.update_xaxes(title_font=dict(size=12))
fig.update_yaxes(title_font=dict(size=12))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d81e0adc-0e8a-4eba-9184-38f9df3a122b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d81e0adc-0e8a-4eba-9184-38f9df3a122b")) {                    Plotly.newPlot(                        "d81e0adc-0e8a-4eba-9184-38f9df3a122b",                        [{"hovertemplate":"typical=Bachelor's degree<br>A_MEAN=%{x}<br>Probability=%{y}<br>TOT_EMP=%{marker.size}<extra></extra>","legendgroup":"Bachelor's degree","marker":{"color":"rgb(229, 134, 6)","opacity":0.5,"size":[200480,200480,2984920,2984920,22520,22520,278690,453800,224620,485190,485190,681070,681070,192270,192270,69310,69310,15330,15330,166530,166530,35830,35830,284750,284750,187100,187100,436770,436770,74760,74760,156400,156400,10320,10320,497890,12480,12480,334340,334340,208950,208950,189320,768450,768450,98150,98150,87750,87750,336030,336030,727540,727540,1030330,1318550,1318550,47440,47440,68770,68770,263030,107690,60750,60750,31230,340170,52270,123200,505150,85870,316760,152610,370190,23040,23040,98700,98700,100400,17430,12610,46390,56640,56640,1120,1120,24180,24180,304310,304310,73750,73750,186020,107170,42660,42660,22870,293950,7380,7380,21530,21530,278240,278240,7370,7370,12670,12670,22100,22100,151940,2790,13510,15610,19430,15930,47050,22550,9500,8520,8520,80600,6690,76890,23620,6390,19680,1440,34330,76150,76150,28690,28690,17020,106340,340050,92140,50790,50790,21000,21000,7320,120730,1329280,592000,11840,1020240,84360,79070,145690,164650,10960,42080,9430,27940,19310,204040,61970,6850,138250,193740,9560,242710,242710,88780,47620,49410,52170,28030,66690,66690,16980,3047530,3047530,6730,6730,426870,426870,266160,59550,59550,5340,5340,6190,6190,13630,13630,81310],"sizemode":"area","sizeref":4103.877777777778,"sym
vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming  \
# 0        280      6320        5910            980       3740      160
# 1        280      6320        5910            980       3740      160
# 258        0       160           0              0          0        0
# 259        0         0           0              0          0        0
#
#      State_Total
# 0         222240
# 1         222240
# 258         3450
# 259         3800
#
# [4 rows x 63 columns]

# %%
table_1 = table_1[['occupation', 'typical', 'TOT_EMP', 'Probability']].drop_duplicates()
# table_1 = table_1.re

# %%
fig = px.scatter(combined_data_2, x='A_MEAN', y='Probability', size='TOT_EMP', color='typical',
                 opacity=0.5, color_discrete_sequence=px.colors.qualitative.Vivid,
                 title='Likelihood of Job Automation vs Median Income',
                 labels={'A_MEDIAN': 'Median Income', 'probability': 'Probability of Automation'},
                 size_max=30, range_y=[-.01, 1], trendline="ols", trendline_scope="overall"
                 ,trendline_color_override="black")

fig.update_traces(marker=dict(line=dict(width=0.5, color='Black')))
fig.update_layout(showlegend=True, legend_title='Education Level', legend=dict(title_font=dict(size=10)))
fig.update_xaxes(title_font=dict(size=12))
fig.update_yaxes(title_font=dict(size=12))


fig.add_trace(px.scatter(combined_data_2[
    (combined_data_2['A_MEAN'] > 175000) & (combined_data_2['Probability'] < 0.05)], x='A_MEAN', y='Probability',
                 labels={'total': 'Number of Americans in a Given Job', 'probability': 'Probability of Automation'},
                 text='occupation', size_max=2.5).update_traces(textposition='top center', showlegend=False).data[0])
fig.add_trace(px.scatter(combined_data_2[
    (combined_data_2['A_MEAN'] > 100000) & (combined_data_2['Probability'] > 0.90)], x='A_MEAN', y='Probability',
                 labels={'total': 'Number of Americans in a Given Job', 'probability': 'Probability of Automation'},
                 text='occupation', size_max=2.5).update_traces(textposition='bottom center', showlegend=False).data[0])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7eaa3ccc-cccb-4d95-a5d4-838390f15fdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eaa3ccc-cccb-4d95-a5d4-838390f15fdb")) {                    Plotly.newPlot(                        "7eaa3ccc-cccb-4d95-a5d4-838390f15fdb",                        [{"hovertemplate":"typical=Bachelor's degree<br>A_MEAN=%{x}<br>Probability=%{y}<br>TOT_EMP=%{marker.size}<extra></extra>","legendgroup":"Bachelor's degree","marker":{"color":"rgb(229, 134, 6)","opacity":0.5,"size":[200480,200480,2984920,2984920,22520,22520,278690,453800,224620,485190,485190,681070,681070,192270,192270,69310,69310,15330,15330,166530,166530,35830,35830,284750,284750,187100,187100,436770,436770,74760,74760,156400,156400,10320,10320,497890,12480,12480,334340,334340,208950,208950,189320,768450,768450,98150,98150,87750,87750,336030,336030,727540,727540,1030330,1318550,1318550,47440,47440,68770,68770,263030,107690,60750,60750,31230,340170,52270,123200,505150,85870,316760,152610,370190,23040,23040,98700,98700,100400,17430,12610,46390,56640,56640,1120,1120,24180,24180,304310,304310
# %%
states = combined_data_2.columns[11:-1]

# %%
p = combined_data_2.sort_values(by=['Probability'], ascending=False)
sum_work_per_state = p[states].sum()
States_sum_DF = pd.DataFrame({'States':sum_work_per_state.index, 'sum_work_positions':sum_work_per_state.values})
States_sum_sort =  States_sum_DF.sort_values(by=['sum_work_positions'], ascending=False)

# %%
States_sum_sort.head()
# Out:
#         States  sum_work_positions
# 4   California            17701210
# 43       Texas            13326870
# 32    New York            10149740
# 9      Florida             9647870
# 13    Illinois             6447580

# %%
# Define a dictionary of state abbreviations
state_abbr = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
}

# %%
len(state_abbr)
# Out:
# 51

# %%
# Use the map() function to apply the state abbreviations to the DataFrame
States_sum_sort["Abbreviation"] = States_sum_sort["States"].map(state_abbr)

# Print the resulting DataFrame
States_sum_sort.head()
# Out:
#         States  sum_work_positions Abbreviation
# 4   California            17701210           CA
# 43       Texas            13326870           TX
# 32    New York            10149740           NY
# 9      Florida             9647870           FL
# 13    Illinois             6447580           IL

# %% [markdown]
# ### Total number of jobs positions per state

# %%
# Use Plotly Express to create a choropleth plot
fig = px.choropleth(States_sum_sort,
                    locations='Abbreviation',  # Column with state names
                    locationmode='USA-states',  # Use USA states as location mode
                    color='sum_work_positions',  # Column with values to be represented by color
                    scope='usa',  # Set the scope to USA
                    color_continuous_scale='Viridis',  # Choose a color scale
                    labels={'sum_work_positions': 'Total Workers'},  # Set custom labels
                    title='Total Employees per States')  # Set a title for the plot

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d8397f95-a0cf-4a08-808a-09ce06d06e3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8397f95-a0cf-4a08-808a-09ce06d06e3d")) {                    Plotly.newPlot(                        "d8397f95-a0cf-4a08-808a-09ce06d06e3d",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Abbreviation=%{location}<br>Total Workers=%{z}<extra></extra>","locationmode":"USA-states","locations":["CA","TX","NY","FL","IL","PA","OH","GA","NC","MI","NJ","VA","MA","WA","IN","TN","WI","MN","MO","AZ","MD","CO","SC","LA","AL","KY","OR","CT","OK","IA","UT","KS","NV","AR","MS","NE","NM","DC","WV","ID","HI","NH","ME","MT","RI","SD","ND","DE","AK","VT","WY"],"name":"","z":[17701210,13326870,10149740,9647870,6447580,6404290,5833870,4797680,4623840,4593490,4291740,4177350,3772060,3388800,3258550,3209950,3137620,3025050,3019530,3000710,2913170,2793630,2258330,2222260,2128470,2007310,1951660,1850430,1825430,1695310,1578650,1525600,1435180,1333020,1232910,1097830,869930,784770,772390,766170,724220,718980,664160,522540,508800,487800,483770,468020,359300,323710,315080],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"} ...

# %%
def barplot(data_in, x_data, y_data, title_in, hue_in, line):
    fig = px.bar(data_in, x=x_data, y=y_data, color=hue_in, barmode='group')
    fig.update_layout(title='\n'.join(title_in), title_font=dict(size=20, color='white', family='Arial'),
                      xaxis_title=title_in , yaxis_title='Value')
    fig.add_shape(type='line', x0=line, x1=line, y0=0, y1=1, xref='x', yref='paper', line=dict(color='red'))
    return fig

# %%
# barplot(States_sum_sort, 'sum_work_positions', 'States', "Total number of jobs positions per state", None, 0)
barplot(States_sum_sort, 'sum_work_positions', 'States', "Total number of jobs positions per state", None, 0)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bbb1cdaf-ec78-4f37-8cf9-cf3643999b98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbb1cdaf-ec78-4f37-8cf9-cf3643999b98")) {                    Plotly.newPlot(                        "bbb1cdaf-ec78-4f37-8cf9-cf3643999b98",                        [{"alignmentgroup":"True","hovertemplate":"sum_work_positions=%{x}<br>States=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[17701210,13326870,10149740,9647870,6447580,6404290,5833870,4797680,4623840,4593490,4291740,4177350,3772060,3388800,3258550,3209950,3137620,3025050,3019530,3000710,2913170,2793630,2258330,2222260,2128470,2007310,1951660,1850430,1825430,1695310,1578650,1525600,1435180,1333020,1232910,1097830,869930,784770,772390,766170,724220,718980,664160,522540,508800,487800,483770,468020,359300,323710,315080],"xaxis":"x","y":["California","Texas","New York","Florida","Illinois","Pennsylvania","Ohio","Georgia","North Carolina","Michigan","New Jersey","Virginia","Massachusetts","Washington","Indiana","Tennessee","Wisconsin","Minnesota","Missouri","Arizona","Maryland","Colorado","South Carolina","Louisiana","Alabama","Kentucky","Oregon","Connecticut","Oklahoma","Iowa","Utah","Kansas","Nevada","Arkansas","Mississippi","Nebraska","New Mexico","District of Columbia","West Virginia","Idaho","Hawaii","New Hampshire","Maine","Montana","Rhode Island","South Dakota","North Dakota","Delaware","Alaska","Vermont","Wyoming"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale" ...

# %% [markdown]
# ### Jobs lost per state when we use automation `thershold < 0.7`

# %%
THERSHOLD = 0.7

# %%
p_less_07_df = combined_data_2.loc[(combined_data_2.Probability < THERSHOLD)]

# %%
sum_work_per_state_p_less_07 = p_less_07_df[states].sum()
States_sum_DF_p_less_07 = pd.DataFrame({'States':sum_work_per_state_p_less_07.index, 'sum_work_positions':sum_work_per_state_p_less_07.values})
States_sum_sort_p_less_07 =  States_sum_DF_p_less_07.sort_values(by=['sum_work_positions'], ascending=False)
States_sum_sort_p_less_07.head()
# Out:
#         States  sum_work_positions
# 4   California             8055980
# 43       Texas             5872910
# 32    New York             4771540
# 9      Florida             4122890
# 13    Illinois             3008160

# %%
barplot(States_sum_sort_p_less_07, 'sum_work_positions', 'States', "Total Jobs per state when p<0.7", None, 0)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d6e5e9d7-3061-4a73-b3e0-fe211af93826" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6e5e9d7-3061-4a73-b3e0-fe211af93826")) {                    Plotly.newPlot(                        "d6e5e9d7-3061-4a73-b3e0-fe211af93826",                        [{"alignmentgroup":"True","hovertemplate":"sum_work_positions=%{x}<br>States=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[8055980,5872910,4771540,4122890,3008160,2795210,2615800,2175950,2095260,2083480,1990640,1942540,1895540,1566610,1446250,1432110,1426510,1424320,1419100,1376220,1300700,1288990,1001570,930330,917300,892820,880830,862640,817560,764310,740860,678760,585150,553170,527080,505360,469550,408700,340580,336560,317240,312370,295080,228580,213590,208830,208770,182940,166830,143110,136010],"xaxis":"x","y":["California","Texas","New York","Florida","Illinois","Pennsylvania","Ohio","Georgia","Michigan","North Carolina","Virginia","Massachusetts","New Jersey","Washington","Maryland","Minnesota","Arizona","Tennessee","Indiana","Wisconsin","Missouri","Colorado","South Carolina","Louisiana","Connecticut","Alabama","Kentucky","Oregon","Oklahoma","Utah","Iowa","Kansas","Arkansas","Nevada","Mississippi","District of Columbia","Nebraska","New Mexico","Idaho","West Virginia","Hawaii","New Hampshire","Maine","Rhode Island","Montana","Delaware","North Dakota","South Dakota","Alaska","Vermont","Wyoming"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...

# %%
p_less_07_df = combined_data_2.loc[(combined_data_2.Probability < THERSHOLD)]

# %%
o2 = combined_data_2.loc[(combined_data_2.Probability < 0.2)]

o2 = o2[states].sum()
o2 = pd.DataFrame({'States':o2.index, 'sum_work_positions':o2.values})
o2 =  o2.sort_values(by=['sum_work_positions'], ascending=False)

o3 = combined_data_2.loc[(combined_data_2.Probability < 0.3)]

o3 = o3[states].sum()
o3 = pd.DataFrame({'States':o3.index, 'sum_work_positions':o3.values})
o3 =  o3.sort_values(by=['sum_work_positions'], ascending=False)

o4 = combined_data_2.loc[(combined_data_2.Probability < 0.4)]

o4 = o4[states].sum()
o4 = pd.DataFrame({'States':o4.index, 'sum_work_positions':o4.values})
o4 =  o4.sort_values(by=['sum_work_positions'], ascending=False)

o5 = combined_data_2.loc[(combined_data_2.Probability < 0.5)]

o5 = o5[states].sum()
o5 = pd.DataFrame({'States':o5.index, 'sum_work_positions':o5.values})
o5 =  o5.sort_values(by=['sum_work_positions'], ascending=False)

o6 = combined_data_2.loc[(combined_data_2.Probability < 0.6)]

o6 = o6[states].sum()
o6 = pd.DataFrame({'States':o6.index, 'sum_work_positions':o6.values})
o6 =  o6.sort_values(by=['sum_work_positions'], ascending=False)

# o7 = combined_data_2.loc[(combined_data_2.Probability < 0.7)]

# o7 = o7[states].sum()
# o7 = pd.DataFrame({'States':o7.index, 'sum_work_positions':o7.values})
# o7 =  o7.sort_values(by=['sum_work_positions'], ascending=False)

o8 = combined_data_2.loc[(combined_data_2.Probability < 0.8)]

o8 = o8[states].sum()
o8 = pd.DataFrame({'States':o8.index, 'sum_work_positions':o8.values})
o8 =  o8.sort_values(by=['sum_work_positions'], ascending=False)


o2['Threshhold'] = 0.2
o3['Threshhold'] = 0.3
o4['Threshhold'] = 0.4
o5['Threshhold'] = 0.5
o6['Threshhold'] = 0.6
# o2['Threshhold'] = 0.7
o8['Threshhold'] = 0.8

# %%
States_sum_sort['Threshhold'] = 1.0
States_sum_sort_p_less_07['Threshhold'] = THERSHOLD

# %%
Compare_thresholds = pd.concat([States_sum_sort, o8, States_sum_sort_p_less_07, o6, o5, o4, o3, o2])

# %%
Compare_thresholds_01_07 = pd.concat([States_sum_sort, States_sum_sort_p_less_07])

# %%
fig = px.bar(Compare_thresholds, x="sum_work_positions", y="States", color="States",
             animation_frame="Threshhold",
             color_discrete_sequence=px.colors.qualitative.Pastel)  # Specify color scale

# Customize the appearance of the chart
fig.update_traces(marker_line_width=0)  # Remove marker outlines
fig.update_layout(title="Comparison of Work Positions by State",  # Add title
                  xaxis_title="Sum of Work Positions",  # Add x-axis title
                  yaxis_title="States" , height=800, xaxis_range=[0 , 18000000] )  # Add y-axis title
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="828f5ee9-fee2-42f3-83b7-469bbd3bd3fa" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("828f5ee9-fee2-42f3-83b7-469bbd3bd3fa")) {                    Plotly.newPlot(                        "828f5ee9-fee2-42f3-83b7-469bbd3bd3fa",                        [{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"California","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""},"line":{"width":0}},"name":"California","offsetgroup":"California","orientation":"h","showlegend":true,"textposition":"auto","x":[17701210],"xaxis":"x","y":["California"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"Texas","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""},"line":{"width":0}},"name":"Texas","offsetgroup":"Texas","orientation":"h","showlegend":true,"textposition":"auto","x":[13326870],"xaxis":"x","y":["Texas"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"New York","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""},"line":{"width":0}},"name":"New York","offsetgroup":"New York","orientation":"h","showlegend":true,"textposition":"auto","x":[10149740],"xaxis":"x","y":["New York"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"Florida","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""},"line":{"width":0}},"name":"Florida","offsetgroup":"Florida","orientation":"h","showlegend":true,"textposition":"auto","x":[9647870],"xaxis":"x","y":["Florida"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"Illinois","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""},"line":{"width":0}},"name":"Illinois","offsetgroup":"Illinois","orientation":"h","showlegend":true,"textposition":"auto","x":[6447580],"xaxis":"x","y":["Illinois"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"Pennsylvania","marker":{"color":"rgb(158, 185, 243)","pattern":{"shape":""},"line":{"width":0}},"name":"Pennsylvania","offsetgroup":"Pennsylvania","orientation":"h","showlegend":true,"textposition":"auto","x":[6404290],"xaxis":"x","y":["Pennsylvania"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"Ohio","marker":{"color":"rgb(254, 136, 177)","pattern":{"shape":""},"line":{"width":0}},"name":"Ohio","offsetgroup":"Ohio","orientation":"h","showlegend":true,"textposition":"auto","x":[5833870],"xaxis":"x","y":["Ohio"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"Georgia","marker":{"color":"rgb(201, 219, 116)","pattern":{"shape":""},"line":{"width":0}},"name":"Georgia","offsetgroup":"Georgia","orientation":"h","showlegend":true,"textposition":"auto","x":[4797680],"xaxis":"x","y":["Georgia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{y}<br>Threshhold=1.0<br>sum_work_positions=%{x}<extra></extra>","legendgroup":"North Carolina","marker":{"color":"rgb(139, 224, 164)","pattern":{"shape":""},"line":{"width":0}},"name":"North Carolina","offsetgroup":"North Carolina","orientation":"h","showlegend":true,"textpo ...

# %%
Compare_thresholds_01_07
# Out:
#           States  sum_work_positions Abbreviation  Threshhold
# 4     California            17701210           CA         1.0
# 43         Texas            13326870           TX         1.0
# 32      New York            10149740           NY         1.0
# 9        Florida             9647870           FL         1.0
# 13      Illinois             6447580           IL         1.0
# ..           ...                 ...          ...         ...
# 34  North Dakota              208770          NaN         0.7
# 41  South Dakota              182940          NaN         0.7
# 1         Alaska              166830          NaN         0.7
# 45       Vermont              143110          NaN         0.7
# 50       Wyoming              136010          NaN         0.7
#
# [102 rows x 4 columns]

# %%
fig = px.histogram(Compare_thresholds_01_07.sort_values(by=['sum_work_positions'], ascending=True),
             x='sum_work_positions', y='States', color='Threshhold',  barmode='group')

fig.update_layout(title='\n'.join("Total number of jobs positions per state now (Threshhold=1.0) and when higher automation probability accupations lost (Threshhold=threshhold)"),
                  title_font=dict(size=20, color='white', family='Arial'),
                  xaxis_title="Total number of jobs positions per state now (Threshhold=1.0) and when higher automation probability accupations lost (Threshhold=threshhold)" ,
                  yaxis_title='Value', height=800)
# fig.add_shape(type='line', x0=0, x1=0, y0=0, y1=1, xref='x', yref='paper', line=dict(color='red'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a0e29bc1-2f5a-4bfe-957c-0a7c09fbe531" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0e29bc1-2f5a-4bfe-957c-0a7c09fbe531")) {                    Plotly.newPlot(                        "a0e29bc1-2f5a-4bfe-957c-0a7c09fbe531",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Threshhold=0.7<br>sum of sum_work_positions=%{x}<br>States=%{y}<extra></extra>","legendgroup":"0.7","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0.7","offsetgroup":"0.7","orientation":"h","showlegend":true,"x":[136010,143110,166830,182940,208770,208830,213590,228580,295080,312370,317240,336560,340580,408700,469550,505360,527080,553170,585150,678760,740860,764310,817560,862640,880830,892820,917300,930330,1001570,1288990,1300700,1376220,1419100,1424320,1426510,1432110,1446250,1566610,1895540,1942540,1990640,2083480,2095260,2175950,2615800,2795210,3008160,4122890,4771540,5872910,8055980],"xaxis":"x","y":["Wyoming","Vermont","Alaska","South Dakota","North Dakota","Delaware","Montana","Rhode Island","Maine","New Hampshire","Hawaii","West Virginia","Idaho","New Mexico","Nebraska","District of Columbia","Mississippi","Nevada","Arkansas","Kansas","Iowa","Utah","Oklahoma","Oregon","Kentucky","Alabama","Connecticut","Louisiana","South Carolina","Colorado","Missouri","Wisconsin","Indiana","Tennessee","Arizona","Minnesota","Maryland","Washington","New Jersey","Massachusetts","Virginia","North Carolina","Michigan","Georgia","Ohio","Pennsylvania","Illinois","Florida","New York","Texas","California"],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Threshhold=1.0<br>sum of sum_work_positions=%{x}<br>States=%{y}<extra></extra>","legendgroup":"1.0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1.0","offsetgroup":"1.0","orientation":"h","showlegend":true,"x":[315080,323710,359300,468020,483770,487800,508800,522540,664160,718980,724220,766170,772390,784770,869930,1097830,1232910,1333020,1435180,1525600,1578650,1695310,1825430,1850430,1951660,2007310,2128470,2222260,2258330,2793630,2913170,3000710,3019530,3025050,3137620,3209950,3258550,3388800,3772060,4177350,4291740,4593490,4623840,4797680,5833870,6404290,6447580,9647870,10149740,13326870,17701210],"xaxis":"x","y":["Wyoming","Vermont","Alaska","Delaware","North Dakota","South Dakota","Rhode Island","Montana","Maine","New Hampshire","Hawaii","Idaho","West Virginia","District of Columbia","New Mexico","Nebraska","Mississippi","Arkansas","Nevada","Kansas","Utah","Iowa","Oklahoma","Connecticut","Oregon","Kentucky","Alabama","Louisiana","South Carolina","Colorado","Maryland","Arizona","Missouri","Minnesota","Wisconsin","Tennessee","Indiana","Washington","Massachusetts","Virginia","New Jersey","Michigan","North Carolina","Georgia","Ohio","Pennsylvania","Illinois","Florida","New York","Texas","California"],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666 ...

# %% [markdown]
# ### what are reliative loss numbers

# %%
States_sum_join = States_sum_sort.join(States_sum_sort_p_less_07, lsuffix='', rsuffix='0.5')
States_sum_drop = States_sum_join.drop(['Threshhold', 'States0.5', 'Threshhold0.5'], axis=1)
Relative_jobs_drop = ((States_sum_drop['sum_work_positions']-States_sum_drop['sum_work_positions0.5'])/States_sum_drop['sum_work_positions'])*100
States_sum_drop.head()
# Out:
#         States  sum_work_positions Abbreviation  sum_work_positions0.5
# 4   California            17701210           CA                8055980
# 43       Texas            13326870           TX                5872910
# 32    New York            10149740           NY                4771540
# 9      Florida             9647870           FL                4122890
# 13    Illinois             6447580           IL                3008160

# %%
Relative_jobs_drop_DF = pd.DataFrame({'Lost jobs ratio':Relative_jobs_drop.values})
Relative_jobs_drop_States = States_sum_drop.join(Relative_jobs_drop_DF)
Relative_jobs_drop_States_sort = Relative_jobs_drop_States.sort_values(by=['sum_work_positions'], ascending=False)
Relative_jobs_drop_mean = Relative_jobs_drop_States_sort['Lost jobs ratio'].mean()
Relative_jobs_drop_mean
# Out:
# 54.966563375478984

# %%
barplot(Relative_jobs_drop_States_sort, 'Lost jobs ratio', 'States', "Lost jobs ratio per state when we lost jobs with automatisation probability equal to 0.7 (Threshhold) or higher", None, Relative_jobs_drop_mean)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8cf42909-8048-4a73-8ce6-117a1b57feb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cf42909-8048-4a73-8ce6-117a1b57feb1")) {                    Plotly.newPlot(                        "8cf42909-8048-4a73-8ce6-117a1b57feb1",                        [{"alignmentgroup":"True","hovertemplate":"Lost jobs ratio=%{x}<br>States=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[53.34435555665846,59.124660313086075,61.456402681196785,54.38631628674494,53.77095136921625,56.42615777003846,57.229261361048614,55.83283237101968,56.10343430706216,55.64997143907223,51.58458176289869,56.8451950306964,53.85967361461611,55.38011196102731,56.44995473446779,55.570946759816906,55.79067684038183,58.13586169035126,56.11888547359401,52.98854946038026,50.35476817350172,56.3541001422484,56.195631161801664,56.92375965796002,54.48909989769061,52.658303168542666,35.6040623367356,55.16183939648981,53.01920844205855,55.627969283010636,55.0746855345912,56.138091929551706,55.212744394471436,57.26631888696676,58.053437445676934,50.427738417557,55.508652333508124,54.94048236963217,53.56804898413582,48.50187960955022,52.346822746478026,56.29943786092218,52.46091758283873,55.799678222641234,55.54772439536917,56.55372889371053,57.24910982959016,54.64578713044638,55.931812946325735,62.49692496924969,56.833185222800566],"xaxis":"x","y":["California","Texas","New York","Florida","Illinois","Pennsylvania","Ohio","Georgia","North Carolina","Michigan","New Jersey","Virginia","Massachusetts","Washington","Indiana","Tennessee","Wisconsin","Minnesota","Missouri","Arizona","Maryland","Colorado","South Carolina","Louisiana","Alabama","Kentucky","Oregon","Connecticut","Oklahoma","Iowa","Utah","Kansas","Nevada","Arkansas","Mississippi","Nebraska","New Mexico","District of Columbia","West Virginia","Idaho","Hawaii","New Hampshire","Maine","Montana","Rhode Island","South Dakota","North Dakota","Delaware","Alaska","Vermont","Wyoming"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"cont ...

# %%
Relative_jobs_drop_States_sort.head()
# Out:
#         States  sum_work_positions Abbreviation  sum_work_positions0.5  \
# 4   California            17701210           CA                8055980
# 43       Texas            13326870           TX                5872910
# 32    New York            10149740           NY                4771540
# 9      Florida             9647870           FL                4122890
# 13    Illinois             6447580           IL                3008160
#
#     Lost jobs ratio
# 4         53.344356
# 43        59.124660
# 32        61.456403
# 9         54.386316
# 13        53.770951

# %%
# Use Plotly Express to create a choropleth plot
fig = px.choropleth(Relative_jobs_drop_States_sort,
                    locations='Abbreviation',  # Column with state names
                    locationmode='USA-states',  # Use USA states as location mode
                    color='Lost jobs ratio',  # Column with values to be represented by color
                    scope='usa',  # Set the scope to USA
                    color_continuous_scale='jet',  # Choose a color scale
                    labels={'Lost jobs ratio': 'Job loss ratio'},  # Set custom labels
                    title='Lost job ratio per state with automation probability of 0.7+ threshold',
                    hover_name='States',  # Add state names to hover information
                    )    # Set a title for the plot

fig.update_geos(
    visible=False, resolution=110, scope="usa",
    showcountries=True, countrycolor="Black",
    showsubunits=True, subunitcolor="Blue"
)

fig.update_layout(geo=dict(bgcolor='white',  # Set background color to white
                            lakecolor='white'),  # Set lake color to white
                  margin=dict(r=20, l=20, t=50, b=20),  # Set margin for the plot
                  coloraxis_colorbar=dict(title='Job Loss Ratio',  # Set colorbar title
                                           ticksuffix='%'),  # Set colorbar tick suffix to percentage
                  title=dict(x=0.5, y=0.95),  # Set title position
                  )
# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fd6e7a75-265c-4bb2-b738-4cbbef4040cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd6e7a75-265c-4bb2-b738-4cbbef4040cd")) {                    Plotly.newPlot(                        "fd6e7a75-265c-4bb2-b738-4cbbef4040cd",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Abbreviation=%{location}<br>Job loss ratio=%{z}<extra></extra>","hovertext":["California","Texas","New York","Florida","Illinois","Pennsylvania","Ohio","Georgia","North Carolina","Michigan","New Jersey","Virginia","Massachusetts","Washington","Indiana","Tennessee","Wisconsin","Minnesota","Missouri","Arizona","Maryland","Colorado","South Carolina","Louisiana","Alabama","Kentucky","Oregon","Connecticut","Oklahoma","Iowa","Utah","Kansas","Nevada","Arkansas","Mississippi","Nebraska","New Mexico","District of Columbia","West Virginia","Idaho","Hawaii","New Hampshire","Maine","Montana","Rhode Island","South Dakota","North Dakota","Delaware","Alaska","Vermont","Wyoming"],"locationmode":"USA-states","locations":["CA","TX","NY","FL","IL","PA","OH","GA","NC","MI","NJ","VA","MA","WA","IN","TN","WI","MN","MO","AZ","MD","CO","SC","LA","AL","KY","OR","CT","OK","IA","UT","KS","NV","AR","MS","NE","NM","DC","WV","ID","HI","NH","ME","MT","RI","SD","ND","DE","AK","VT","WY"],"name":"","z":[53.34435555665846,59.124660313086075,61.456402681196785,54.38631628674494,53.77095136921625,56.42615777003846,57.229261361048614,55.83283237101968,56.10343430706216,55.64997143907223,51.58458176289869,56.8451950306964,53.85967361461611,55.38011196102731,56.44995473446779,55.570946759816906,55.79067684038183,58.13586169035126,56.11888547359401,52.98854946038026,50.35476817350172,56.3541001422484,56.195631161801664,56.92375965796002,54.48909989769061,52.658303168542666,35.6040623367356,55.16183939648981,53.01920844205855,55.627969283010636,55.0746855345912,56.138091929551706,55.212744394471436,57.26631888696676,58.053437445676934,50.427738417557,55.508652333508124,54.94048236963217,53.56804898413582,48.50187960955022,52.346822746478026,56.29943786092218,52.46091758283873,55.799678222641234,55.54772439536917,56.55372889371053,57.24910982959016,54.64578713044638,55.931812946325735,62.49692496924969,56.833185222800566],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333 ...

# %%
Relative_jobs_drop_States_highest = Relative_jobs_drop_States.sort_values(by=['Lost jobs ratio'], ascending=False)

# %%
barplot(Relative_jobs_drop_States_highest, 'Lost jobs ratio', 'States', "Lost jobs ratio per state when we lost jobs with automatisation probability equal to 0.7 (Threshhold) or higher", None, Relative_jobs_drop_mean)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7b7ed3a1-8e04-4012-b0a7-1c9fb5cf9cd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b7ed3a1-8e04-4012-b0a7-1c9fb5cf9cd6")) {                    Plotly.newPlot(                        "7b7ed3a1-8e04-4012-b0a7-1c9fb5cf9cd6",                        [{"alignmentgroup":"True","hovertemplate":"Lost jobs ratio=%{x}<br>States=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[62.49692496924969,61.456402681196785,59.124660313086075,58.13586169035126,58.053437445676934,57.26631888696676,57.24910982959016,57.229261361048614,56.92375965796002,56.8451950306964,56.833185222800566,56.55372889371053,56.44995473446779,56.42615777003846,56.3541001422484,56.29943786092218,56.195631161801664,56.138091929551706,56.11888547359401,56.10343430706216,55.931812946325735,55.83283237101968,55.799678222641234,55.79067684038183,55.64997143907223,55.627969283010636,55.570946759816906,55.54772439536917,55.508652333508124,55.38011196102731,55.212744394471436,55.16183939648981,55.0746855345912,54.94048236963217,54.64578713044638,54.48909989769061,54.38631628674494,53.85967361461611,53.77095136921625,53.56804898413582,53.34435555665846,53.01920844205855,52.98854946038026,52.658303168542666,52.46091758283873,52.346822746478026,51.58458176289869,50.427738417557,50.35476817350172,48.50187960955022,35.6040623367356],"xaxis":"x","y":["Vermont","New York","Texas","Minnesota","Mississippi","Arkansas","North Dakota","Ohio","Louisiana","Virginia","Wyoming","South Dakota","Indiana","Pennsylvania","Colorado","New Hampshire","South Carolina","Kansas","Missouri","North Carolina","Alaska","Georgia","Montana","Wisconsin","Michigan","Iowa","Tennessee","Rhode Island","New Mexico","Washington","Nevada","Connecticut","Utah","District of Columbia","Delaware","Alabama","Florida","Massachusetts","Illinois","West Virginia","California","Oklahoma","Arizona","Kentucky","Maine","Hawaii","New Jersey","Nebraska","Maryland","Idaho","Oregon"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"cont ...

# %% [markdown]
# Vermont and Texas have most jobs losses. Lets look, what are biggest occupations they lost

# %%
Vermont = combined_data_2[['occupation', 'Probability', 'Texas', 'Vermont']].sort_values(by=['Probability'], ascending=False)
Vermont_full = Vermont.loc[(Vermont.Probability >= THERSHOLD)].sort_values(by=['Vermont'], ascending=False).reset_index()
Vermont = Vermont_full.head(9)
Vermont_tail = Vermont_full.tail(308).Vermont.sum()
df2 = {'occupation': 'Other', 'Probability': 0, 'Texas': 0, 'Vermont': Vermont_tail}
Vermont = Vermont.append(df2, ignore_index = True)
Vermont
# Out:
# <ipython-input-88-19227bc9de89>:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#    index                                         occupation  Probability  \
# 0  395.0                                           cashiers         0.97
# 1  396.0                                           cashiers         0.97
# 2  400.0                                retail salespersons         0.92
# 3  399.0                                retail salespersons         0.92
# 4  485.0  secretaries and administrative assistants, exc...         0.96
# 5  431.0       bookkeeping, accounting, and auditing clerks         0.98
# 6  430.0       bookkeeping, accounting, and auditing clerks         0.98
# 7  348.0                             waiters and waitresses         0.94
# 8  347.0                             waiters and waitresses         0.94
# 9    NaN                                              Other         0.00
#
#     Texas  Vermont
# 0  272270     9700
# 1  272270     9700
# 2  383080     9100
# 3  383080     9100
# 4  176670     5970
# 5  125140     5450
# 6  125140     5450
# 7  219680     5400
# 8  219680     5400
# 9       0    35830

# %%
import plotly.express as px

# Create a list of colors
colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B", "#EB8076", "#96624E"]

def plot_pie(data_in, title_in, labels_in):
    '''
    Inputs:
        data_in: Data Frame of objects and floats;
        title_in: string, chart title;
        labels_in: object, occupation name.
    Output:
        pie chart.
    '''
    fig = px.pie(data_in,
                 values=data_in,
                 names=labels_in,
                 color_discrete_sequence=colors,  # Set colors
                 title=title_in,
                 hover_name=labels_in,
                 labels={'value': 'Percentage'},  # Set custom labels
                 hole=0.4,  # Set donut hole size
                 )
    # fig.update_traces(textposition='outside',  # Set text position inside the pie
    #                   textinfo='percent+label')  # Set text info to display percent and label
    fig.update_layout(title_text=title_in, title_font=dict(size=20),  # Set title font size and weight
                      showlegend=True)  # Hide legend

    fig.update_traces(pull=0.05)

    fig.show()  # Show the chart

# %%
plot_pie(Vermont['Vermont'], "The largest most likely automatable occupations in Vermont", Vermont['occupation'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e0f8b492-5df2-40b6-aee0-76255aad2f8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0f8b492-5df2-40b6-aee0-76255aad2f8a")) {                    Plotly.newPlot(                        "e0f8b492-5df2-40b6-aee0-76255aad2f8a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"<b>%{hovertext}</b><br><br>label=%{label}<br>value=%{value}<extra></extra>","hovertext":["cashiers","cashiers","retail salespersons","retail salespersons","secretaries and administrative assistants, except legal, medical, and executive","bookkeeping, accounting, and auditing clerks","bookkeeping, accounting, and auditing clerks","waiters and waitresses","waiters and waitresses","Other"],"labels":["cashiers","cashiers","retail salespersons","retail salespersons","secretaries and administrative assistants, except legal, medical, and executive","bookkeeping, accounting, and auditing clerks","bookkeeping, accounting, and auditing clerks","waiters and waitresses","waiters and waitresses","Other"],"legendgroup":"","name":"","showlegend":true,"values":[9700,9700,9100,9100,5970,5450,5450,5400,5400,35830],"type":"pie","pull":0.05}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode ...

# %%
Texas = combined_data_2[['occupation', 'Probability', 'Texas']].sort_values(by=['Probability'], ascending=False)
Texas_full = Texas.loc[(Texas.Probability >= THERSHOLD)].sort_values(by=['Texas'], ascending=False).reset_index()
Texas = Texas_full.head(9)
Texas_tail = Texas_full.tail(308)['Texas'].sum()
df2 = {'occupation': 'Other', 'Probability': 0, 'Texas': Texas_tail}
Texas = Texas.append(df2, ignore_index = True)
Texas
# Out:
# <ipython-input-91-346d2098a086>:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#    index                                         occupation  Probability  \
# 0  400.0                                retail salespersons         0.92
# 1  399.0                                retail salespersons         0.92
# 2  495.0                             office clerks, general         0.96
# 3  494.0                             office clerks, general         0.96
# 4  396.0                                           cashiers         0.97
# 5  395.0                                           cashiers         0.97
# 6  348.0                             waiters and waitresses         0.94
# 7  347.0                             waiters and waitresses         0.94
# 8  788.0  laborers and freight, stock, and material move...         0.85
# 9    NaN                                              Other         0.00
#
#      Texas
# 0   383080
# 1   383080
# 2   363020
# 3   363020
# 4   272270
# 5   272270
# 6   219680
# 7   219680
# 8   178880
# 9  1678860

# %%
plot_pie(Texas['Texas'], "The largest most likely automatable occupations in Texas", Texas['occupation'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7e124427-db7b-4bc9-ab20-cb8dadcb7545" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e124427-db7b-4bc9-ab20-cb8dadcb7545")) {                    Plotly.newPlot(                        "7e124427-db7b-4bc9-ab20-cb8dadcb7545",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"<b>%{hovertext}</b><br><br>label=%{label}<br>value=%{value}<extra></extra>","hovertext":["retail salespersons","retail salespersons","office clerks, general","office clerks, general","cashiers","cashiers","waiters and waitresses","waiters and waitresses","laborers and freight, stock, and material movers, hand","Other"],"labels":["retail salespersons","retail salespersons","office clerks, general","office clerks, general","cashiers","cashiers","waiters and waitresses","waiters and waitresses","laborers and freight, stock, and material movers, hand","Other"],"legendgroup":"","name":"","showlegend":true,"values":[383080,383080,363020,363020,272270,272270,219680,219680,178880,1678860],"type":"pie","pull":0.05}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outline ...

# %% [markdown]
# District of Oregon has lowest sensitivity for automation. Let's check the data

# %%
Oregon = combined_data_2[['occupation', 'Probability', 'Oregon']].sort_values(by=['Probability'], ascending=False)
Oregon_full = Oregon.loc[(Oregon.Probability >= THERSHOLD)].sort_values(by=['Oregon'], ascending=False).reset_index()
Oregon = Oregon_full.head(9)
Oregon_tail = Oregon_full.tail(308)['Oregon'].sum()
df2 = {'occupation': 'Other', 'Probability': 0, 'Oregon': Oregon_tail}
Oregon = Oregon.append(df2, ignore_index = True)
Oregon
# Out:
# <ipython-input-93-ff3520a4465d>:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#    index                                         occupation  Probability  \
# 0  399.0                                retail salespersons         0.92
# 1  400.0                                retail salespersons         0.92
# 2  395.0                                           cashiers         0.97
# 3  396.0                                           cashiers         0.97
# 4  495.0                             office clerks, general         0.96
# 5  494.0                             office clerks, general         0.96
# 6  348.0                             waiters and waitresses         0.94
# 7  347.0                             waiters and waitresses         0.94
# 8  485.0  secretaries and administrative assistants, exc...         0.96
# 9    NaN                                              Other         0.00
#
#    Oregon
# 0   61610
# 1   61610
# 2   45730
# 3   45730
# 4   33500
# 5   33500
# 6   33100
# 7   33100
# 8   26820
# 9  252520

# %%
plot_pie(Oregon['Oregon'], "The largest most likely automatable occupations in Oregon", Oregon['occupation'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="72e1d659-3548-41cc-ae64-21eff8703044" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72e1d659-3548-41cc-ae64-21eff8703044")) {                    Plotly.newPlot(                        "72e1d659-3548-41cc-ae64-21eff8703044",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"<b>%{hovertext}</b><br><br>label=%{label}<br>value=%{value}<extra></extra>","hovertext":["retail salespersons","retail salespersons","cashiers","cashiers","office clerks, general","office clerks, general","waiters and waitresses","waiters and waitresses","secretaries and administrative assistants, except legal, medical, and executive","Other"],"labels":["retail salespersons","retail salespersons","cashiers","cashiers","office clerks, general","office clerks, general","waiters and waitresses","waiters and waitresses","secretaries and administrative assistants, except legal, medical, and executive","Other"],"legendgroup":"","name":"","showlegend":true,"values":[61610,61610,45730,45730,33500,33500,33100,33100,26820,252520],"type":"pie","pull":0.05}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type": ...
